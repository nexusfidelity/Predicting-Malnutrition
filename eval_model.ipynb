# %%
from pycaret.classification import *
import pandas as pd

# %%
from pycaret.datasets import get_data
data = get_data('dataset/total_0-5_children')
# Out:
#           Region    Province  age  sex  weight      height  \
# 0  Ilocos Region  Ilocos Sur  5.0    1   11.90   97.000000
# 1  Ilocos Region    La Union  5.0    1   11.90   98.900002
# 2  Ilocos Region    La Union  5.0    1   12.65  100.850000
# 3  Ilocos Region    La Union  5.0    1   12.80  100.050000
# 4  Ilocos Region  Pangasinan  5.0    1   13.00  100.950000
#
#               stunted           wasted        bmi    bmi range  year  \
# 0  moderately stunted  severely wasted  12.647465  underweight  2008
# 1  moderately stunted  severely wasted  12.166183  underweight  2008
# 2              normal  severely wasted  12.437661  underweight  2008
# 3              normal  severely wasted  12.787210  underweight  2008
# 4              normal  severely wasted  12.756476  underweight  2008
#
#   weight_status
# 0   underweight
# 1   underweight
# 2   underweight
# 3   underweight
# 4   underweight

# %%
df = pd.read_csv('dataset/total_0-5_children.csv')

# %%
stunting_model = load_model('models/stunting_model')
wasting_model = load_model('models/wasting_model')
weight_model = load_model('models/weight_status_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded

# %%
stunting_setup = setup(data = data,  
                       target = 'stunted',
                       ignore_features = ['Region','Province','wasted','bmi','bmi range','year','weight_status'],
#                        use_gpu=True,
#                        fix_imbalance=True
                       session_id=123,
                )
# Out:
# <style type="text/css">
# #T_b6575_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b6575">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6575_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b6575_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6575_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6575_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b6575_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6575_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b6575_row1_col1" class="data row1 col1" >stunted</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6575_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b6575_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6575_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_b6575_row3_col1" class="data row3 col1" >moderately stunted: 0, normal: 1, severely stunted: 2</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6575_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_b6575_row4_col1" class="data row4 col1" >(114813, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6575_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_b6575_row5_col1" class="data row5 col1" >(114813, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6575_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_b6575_row6_col1" class="data row6 col1" >(80369, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6575_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_b6575_row7_col1" class="data row7 col1" >(34444, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b6575_row8_col0" class="data row8 col0" >Ignore features</td>
#       <td id="T_b6575_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b6575_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_b6575_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b6575_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_b6575_row10_col1" class="data row10 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b6575_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_b6575_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b6575_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_b6575_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b6575_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_b6575_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b6575_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_b6575_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b6575_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_b6575_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b6575_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_b6575_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b6575_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_b6575_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b6575_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_b6575_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b6575_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_b6575_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b6575_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_b6575_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b6575_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b6575_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_b6575_row21_col1" class="data row21 col1" >f401</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate_model(stunting_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df_wasting = df[df['wasted'].notna()]
df_wasting
# Out:
#                          Region           Province  age  sex  weight  \
# 0                 Ilocos Region         Ilocos Sur  5.0    1  11.900
# 1                 Ilocos Region           La Union  5.0    1  11.900
# 2                 Ilocos Region           La Union  5.0    1  12.650
# 3                 Ilocos Region           La Union  5.0    1  12.800
# 4                 Ilocos Region         Pangasinan  5.0    1  13.000
# ...                         ...                ...  ...  ...     ...
# 114808      Zamboanga Peninsula  Zamboanga del Sur  0.0    1   6.825
# 114809      Zamboanga Peninsula  Zamboanga del Sur  0.0    0   6.075
# 114810      Zamboanga Peninsula  Zamboanga Sibugay  0.0    0   5.025
# 114811             Bicol Region           Sorsogon  0.0    0   3.730
# 114812  National Capital Region           East NCR  0.0    1   3.650
#
#             height             stunted             wasted        bmi  \
# 0        97.000000  moderately stunted    severely wasted  12.647465
# 1        98.900002  moderately stunted    severely wasted  12.166183
# 2       100.850000              normal    severely wasted  12.437661
# 3       100.050000              normal    severely wasted  12.787210
# 4       100.950000              normal    severely wasted  12.756476
# ...            ...                 ...                ...        ...
# 114808   65.300003              normal  moderately wasted  16.005758
# 114809   62.650002              normal  moderately wasted  15.477617
# 114810   55.549999              normal  moderately wasted  16.284257
# 114811   51.150000              normal  moderately wasted  14.256652
# 114812   53.250000              normal  moderately wasted  12.872226
#
#           bmi range  year weight_status
# 0       underweight  2008   underweight
# 1       underweight  2008   underweight
# 2       underweight  2008   underweight
# 3       underweight  2008   underweight
# 4       underweight  2008   underweight
# ...             ...   ...           ...
# 114808  underweight  2015         obese
# 114809  underweight  2015         obese
# 114810  underweight  2015         obese
# 114811  underweight  2018        normal
# 114812  underweight  2018        normal
#
# [114563 rows x 12 columns]

# %%
wasting_setup = setup(data = df_wasting,  
                      target = 'wasted',
                      ignore_features = ['Region','Province','stunted','bmi','bmi range','year','weight_status'],
#                       use_gpu=True,
#                       fix_imbalance=True
                      session_id=123,
                )
# Out:
# <style type="text/css">
# #T_55d37_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_55d37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55d37_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_55d37_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55d37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55d37_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_55d37_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55d37_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_55d37_row1_col1" class="data row1 col1" >wasted</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55d37_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_55d37_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55d37_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_55d37_row3_col1" class="data row3 col1" >moderately wasted: 0, normal: 1, severely wasted: 2</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55d37_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_55d37_row4_col1" class="data row4 col1" >(114563, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_55d37_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_55d37_row5_col1" class="data row5 col1" >(114563, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_55d37_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_55d37_row6_col1" class="data row6 col1" >(80194, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_55d37_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_55d37_row7_col1" class="data row7 col1" >(34369, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_55d37_row8_col0" class="data row8 col0" >Ignore features</td>
#       <td id="T_55d37_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_55d37_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_55d37_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_55d37_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_55d37_row10_col1" class="data row10 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_55d37_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_55d37_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_55d37_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_55d37_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_55d37_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_55d37_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_55d37_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_55d37_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_55d37_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_55d37_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_55d37_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_55d37_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_55d37_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_55d37_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_55d37_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_55d37_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_55d37_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_55d37_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_55d37_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_55d37_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_55d37_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_55d37_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_55d37_row21_col1" class="data row21 col1" >7c7d</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate_model(wasting_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
weight_setup = setup(data = data,  
                     target = 'weight_status',
                     ignore_features = ['Region','Province','stunted','bmi','bmi range','year','wasted'],
#                      use_gpu=True,
#                      fix_imbalance=True
                     session_id=123,
                )
# Out:
# <style type="text/css">
# #T_44599_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_44599">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44599_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_44599_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44599_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44599_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_44599_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44599_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_44599_row1_col1" class="data row1 col1" >weight_status</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44599_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_44599_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44599_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_44599_row3_col1" class="data row3 col1" >normal: 0, obese: 1, overweight: 2, underweight: 3</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44599_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_44599_row4_col1" class="data row4 col1" >(114813, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_44599_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_44599_row5_col1" class="data row5 col1" >(114813, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_44599_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_44599_row6_col1" class="data row6 col1" >(80369, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_44599_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_44599_row7_col1" class="data row7 col1" >(34444, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_44599_row8_col0" class="data row8 col0" >Ignore features</td>
#       <td id="T_44599_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_44599_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_44599_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_44599_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_44599_row10_col1" class="data row10 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_44599_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_44599_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_44599_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_44599_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_44599_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_44599_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_44599_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_44599_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_44599_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_44599_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_44599_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_44599_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_44599_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_44599_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_44599_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_44599_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_44599_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_44599_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_44599_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_44599_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_44599_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_44599_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_44599_row21_col1" class="data row21 col1" >c994</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate_model(weight_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
